# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
import numpy as np

data = np.array([[0,0],[0,1],[1,0],[1,1]])
label = np.array([[0],[1],[1],[0]])

class Network(nn.Module):
  def __init_(self):
    super(Network,self).__init__()
    self.layer_1 = nn.Linear(2,4)
    self.layer_2 = nn.Linear(4,4)
    self.layer_3 = nn.Linear(4,1)
    
  def forward(self,output_):
    output_ = F.sigmoid(self.layer_1(output_))
    output_ = F.sigmoid(self.layer_2(output_))
    output_ = F.sigmoid(self.layer_3(output_))
    return output_

network = Network()
optimizer = torch.optim.SGD(network.parameters(), lr=0.1, momentum = 0.9)
loss_func = nn.MSELoss()
epoch = 1000
for epo in range(epoch):
  for idx in range(4):
    data_x = torch.tensor([data[idx]])
    label_x = torch.tensor([label[idx]])
    optimizer.zero_grad()
    network_output = network(data_x.float())
    loss = loss_func(network_output,label_x.float())
    loss.backward()
    optimizer.step()

print(network(torch.tensor([data[0]]).float()))
print(network(torch.tensor([data[1]]).float()))
print(network(torch.tensor([data[2]]).float()))
print(network(torch.tensor([data[3]]).float()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-042b2796eec1> in <module>()
#      21
#      22 network = Network()
# ---> 23 optimizer = torch.optim.SGD(network.parameters(), lr=0.1, momentum = 0.9)
#      24 loss_func = nn.MSELoss()
#      25 epoch = 1000
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/sgd.py in __init__(self, params, lr, momentum, dampening, weight_decay, nesterov)
#      66         if nesterov and (momentum <= 0 or dampening != 0):
#      67             raise ValueError("Nesterov momentum requires a momentum and zero dampening")
# ---> 68         super(SGD, self).__init__(params, defaults)
#      69
#      70     def __setstate__(self, state):
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/optimizer.py in __init__(self, params, defaults)
#      44         param_groups = list(params)
#      45         if len(param_groups) == 0:
# ---> 46             raise ValueError("optimizer got an empty parameter list")
#      47         if not isinstance(param_groups[0], dict):
#      48             param_groups = [{'params': param_groups}]
#
# ValueError: optimizer got an empty parameter list
