# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-02e2e5c5-e3e4-417b-9044-b4b0a0ed099b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02e2e5c5-e3e4-417b-9044-b4b0a0ed099b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bump_01.csv to Bump_01.csv
# Saving Bump_02.csv to Bump_02.csv

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
# %matplotlib inline

# %%
labels = ["Bump", "Harsh_Acceleration", "Risky_Maneveur", "Risky_Distance"]
dataset_bump_01 = pd.DataFrame(pd.read_csv('Bump_01.csv'))
dataset_bump_02 = pd.DataFrame(pd.read_csv('Bump_02.csv'))

# %%
dataset_bump_01["Accel_X"] = (dataset_bump_01["Accel_X"] + 20) / 40
dataset_bump_01["Accel_Y"] = (dataset_bump_01["Accel_Y"] + 20) / 40
dataset_bump_01["Accel_Z"] = (dataset_bump_01["Accel_Z"] + 20) / 40
dataset_bump_01["SPEED"] = (dataset_bump_01["SPEED"]) / 120
dataset_bump_01["STEERING"] = (dataset_bump_01["STEERING"]) / 84
dataset_bump_01["DISTANCE"] = (dataset_bump_01["DISTANCE"]) / 200

dataset_bump_02["Accel_X"] = (dataset_bump_02["Accel_X"] + 20) / 40
dataset_bump_02["Accel_Y"] = (dataset_bump_02["Accel_Y"] + 20) / 40
dataset_bump_02["Accel_Z"] = (dataset_bump_02["Accel_Z"] + 20) / 40
dataset_bump_02["SPEED"] = (dataset_bump_02["SPEED"]) / 120
dataset_bump_02["STEERING"] = (dataset_bump_02["STEERING"]) / 84
dataset_bump_02["DISTANCE"] = (dataset_bump_02["DISTANCE"]) / 200

# %%
dataset_bump_01
# Out:
#      Accel_X  Accel_Y  Accel_Z  SPEED  STEERING  DISTANCE
# 0    -0.1772  -0.0694   9.7600      0        42       180
# 1    -0.1784  -0.0706   9.7564      0        42       180
# 2    -0.1772  -0.0694   9.7588      0        42       180
# 3    -0.1772  -0.0706   9.7588      0        42       180
# 4    -0.1760  -0.0670   9.7600      0        42       180
# ..       ...      ...      ...    ...       ...       ...
# 395  -0.1425  -0.0718   9.7564      0        42       180
# 396  -0.1437  -0.0706   9.7540      0        42       180
# 397  -0.1437  -0.0718   9.7552      0        42       180
# 398  -0.1425  -0.0730   9.7576      0        42       180
# 399  -0.1425  -0.0730   9.7576      0        42       180
#
# [400 rows x 6 columns]

# %%
modified_dataset_bump_01 = dataset_bump_01
modified_dataset_bump_02 = dataset_bump_02
modified_dataset_bump_02
# Out:
#       Accel_X   Accel_Y   Accel_Z  SPEED  STEERING  DISTANCE
# 0    0.495242  0.498385  0.744148    0.0       0.5       0.9
# 1    0.495152  0.498415  0.744000    0.0       0.5       0.9
# 2    0.495183  0.498355  0.744000    0.0       0.5       0.9
# 3    0.495242  0.498325  0.744060    0.0       0.5       0.9
# 4    0.495242  0.498295  0.744148    0.0       0.5       0.9
# ..        ...       ...       ...    ...       ...       ...
# 395  0.496050  0.500270  0.744090    0.0       0.5       0.9
# 396  0.496050  0.500270  0.744090    0.0       0.5       0.9
# 397  0.496110  0.500390  0.744090    0.0       0.5       0.9
# 398  0.496110  0.500420  0.744060    0.0       0.5       0.9
# 399  0.496110  0.500420  0.744148    0.0       0.5       0.9
#
# [400 rows x 6 columns]

# %%
myarray_01 = np.array(modified_dataset_bump_01)
myarray_02 = np.array(modified_dataset_bump_02)
myarray_01 = myarray_01.flatten()
myarray_02 = myarray_02.flatten()
myarray = np.array([myarray_01,myarray_02],'f')
myarray
# Out:
# array([[0.49557  , 0.498265 , 0.744    , ..., 0.       , 0.5      ,
#         0.9      ],
#        [0.4952425, 0.498385 , 0.7441475, ..., 0.       , 0.5      ,
#         0.9      ]], dtype=float32)
